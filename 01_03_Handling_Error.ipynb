# %% [markdown]
# # 1.3 - Handling Error

# %% [markdown]
# Error message is important information to identify mistakes in our program.
#
# Type
# `print(book)`

# %%
print(book)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(book)
#
# NameError: name 'book' is not defined
