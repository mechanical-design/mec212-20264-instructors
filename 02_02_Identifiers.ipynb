# %% [markdown]
# ## 2.2 Identifiers, Variables, and Constants
# Identifiers are names for data in your program.
# Mechanical example: material constants (fixed) and measured dimensions (changing).

# %%
# Tutorial Example 1: Clear engineering variable names
shaft_diameter_mm = 32
bearing_span_mm = 420
cutting_speed_m_per_s = 1.8

print(shaft_diameter_mm, bearing_span_mm, cutting_speed_m_per_s)

# %%
# Tutorial Example 2: Constants by convention (ALL_CAPS)
PI = 3.14159
GRAVITY = 9.81
STEEL_DENSITY = 7850

print(f"g = {GRAVITY} m/s^2, rho_steel = {STEEL_DENSITY} kg/m^3")

# %%
# Tutorial Example 3: Variables can change during process monitoring
tool_temperature_c = 45
print(f"Initial tool temperature: {tool_temperature_c} degC")

tool_temperature_c = 52
print(f"Updated tool temperature: {tool_temperature_c} degC")

# %% [markdown]
# ### Exercise 2.2.1 (Guided)
# Create variables for spindle speed (rpm) and feed rate (mm/rev), and a constant for MAX_SPINDLE_RPM. Print all values.

# %%
# TODO: Define two process variables and one uppercase constant, then print them
# Your code here

# %%
# ===== SOLUTION START =====
spindle_speed_rpm = 1200
feed_rate_mm_per_rev = 0.20
MAX_SPINDLE_RPM = 3000

print(f"Spindle speed: {spindle_speed_rpm} rpm")
print(f"Feed rate: {feed_rate_mm_per_rev} mm/rev")
print(f"Max spindle speed: {MAX_SPINDLE_RPM} rpm")
# ===== SOLUTION END =====

# %% [markdown]
# ### Exercise 2.2.2 (Semi-Independent)
# Use constants for aluminum density (2700 kg/m^3), and variables length = 1.2 m, area = 0.0008 m^2. Compute mass.

# %%
# TODO: Compute bar mass from density constant and geometric variables
# Your code here

# %%
# ===== SOLUTION START =====
RHO_AL = 2700
length_m = 1.2
area_m2 = 0.0008

volume_m3 = length_m * area_m2
mass_kg = RHO_AL * volume_m3

print(f"Volume: {volume_m3:.6f} m^3")
print(f"Mass: {mass_kg:.3f} kg")
# ===== SOLUTION END =====

# %% [markdown]
# ### Exercise 2.2.3 (Independent)
# Given candidate names: ["load_1", "2stress", "for", "beamLength", "yield_strength"],
# print which names are valid Python identifiers and not keywords.

# %%
# TODO: Check identifier validity using isidentifier and keyword checks
# Your code here

# %%
# ===== SOLUTION START =====
import keyword

candidates = ["load_1", "2stress", "for", "beamLength", "yield_strength"]
for name in candidates:
    is_valid = name.isidentifier() and not keyword.iskeyword(name)
    print(f"{name}: {is_valid}")
# ===== SOLUTION END =====
