# %% [markdown]
# # 0.1 Subtopic
#
# Explanation of the subtopic.

# %%
# Example 1

# %%
# Example 2

# %% [markdown]
# ### Exercise 0.1.1
#
# Write exercises here.

# %%
#TODO: Write your code here.

# %%
# ===== SOLUTION START =====
# Solution code goes here
# ==== SOLUTION END =====

# %% [markdown]
# ### Exercise 0.1.2
#
# Write exercises here.

# %%
#TODO: Write your code here.

# %%
# ===== SOLUTION START =====
# Solution code goes here
# ==== SOLUTION END =====
