# %% [markdown]
# # 1.2 Introduction to basic program structure

# %% [markdown]
# Basic program structure defines how code is organized from top to bottom so that both the computer (which executes it) and human developers (who read and maintain it) can understand it effortlessly.
#
# In top-to-bottom programming languages like Python, code is executed sequentially.

# %%
# Example 1
# Import the math module to access mathematical functions and constants
import math

# Get the value of pi from the math module
pi_value = math.pi

# Print the value of pi
print(pi_value)
# Out:
# 3.141592653589793

# %% [markdown]
# ### Exercise 1.2.1
#
# Copy paste the code below to show mathematical constant $e$ (Euler's number). Explain why the code produce error.
#
# ```python
# import math
# e_value = math.e
# print(e_value)
#
# ```

# %%
#TODO: Write your code here.

# %%
# ===== SOLUTION START =====
import math
print(e_value)
e_value = math.e

print('The error occurred because the variable e_value was used before it was defined. In Python, variables must be defined before they can be used. To fix this error, we need to define e_value before we try to print it.')
# ===== SOLUTION END =====
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 # ===== SOLUTION START =====
#       2 import math
# ----> 3 print(e_value)
#       4 e_value = math.e
#       6 print('The error occurred because the variable e_value was used before it was defined. In Python, variables must be defined before they can be used. To fix this error, we need to define e_value before we try to print it.')
#
# NameError: name 'e_value' is not defined
